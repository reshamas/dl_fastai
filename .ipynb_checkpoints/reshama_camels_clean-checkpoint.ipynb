# %%
import fastai
fastai.show_install(0)
# Out:
# ```text
# === Software ===
# python version  : 3.6.5
# fastai version  : 1.0.14
# torch version   : 1.0.0.dev20181022
# nvidia driver   : 396.44
# torch cuda ver  : 9.2.148
# torch cuda is   : available
# torch cudnn ver : 7104
# torch cudnn is  : enabled
#
# === Hardware ===
# nvidia gpus     : 1
# torch available : 1
#   - gpu0        : 7611MB | Tesla P4
#
# === Environment ===
# platform        : Linux-4.9.0-8-amd64-x86_64-with-debian-9.5
# distro          : #1 SMP Debian 4.9.110-3+deb9u6 (2018-10-08)
# conda env       : Unknown
# python          : /opt/anaconda3/bin/python
# sys.path        :
# /opt/anaconda3/lib/python36.zip
# /opt/anaconda3/lib/python3.6
# /opt/anaconda3/lib/python3.6/lib-dynload
# /opt/anaconda3/lib/python3.6/site-packages
# /opt/anaconda3/lib/python3.6/site-packages/IPython/extensions
# /home/jupyter/.ipython
# ```
#
# Please make sure to include opening/closing ``` when you paste into forums/github to make the reports appear formatted as code sections.
#
# Optional package(s) to enhance the diagnostics can be installed with:
# pip install distro
# Once installed, re-run this utility to get the additional information

# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button. Then continue scrolling until you cannot scroll anymore. The maximum number of images Google Images shows is 700.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
my_path = "/home/jupyter/tutorials/"

# %%
folder = 'camels'
file = 'urls_camels.txt'

# %%
path = Path(my_path+'data/mammals')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
folder = 'horses'
file = 'urls_horses.txt'

# %%
path = Path(my_path+'data/mammals')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Finally, upload your urls file. You just need to press Upload in your working directory and select your file, then click 'upload' on the right.
#
# ![](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images than can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.

# %%
my_path = "/home/jupyter/tutorials/"

# %%
# !head {my_path}data/mammals/urls_horses.txt
# Out:
# https://upload.wikimedia.org/wikipedia/commons/d/de/Nokota_Horses_cropped.jpg
# https://equusmagazine.com/.image/t_share/MTQ1Mjc2NDE4Mzk1MjE5MzUy/feral-horse-and-foal-walk-along-the-beach-on-vieques-island-off-puerto-rico.jpg
# https://i.ytimg.com/vi/_Yz0VL0GsNM/hqdefault.jpg
# https://media.treehugger.com/assets/images/2018/02/three-horses.jpg.860x0_q70_crop-scale.jpg
# https://www.equinenow.com/content/american-quarter-horse.jpg
# https://www.sciencenews.org/sites/default/files/2018/02/main/articles/022118_EE_horses_feat.jpg
# https://thehorse.com/wp-content/uploads/2017/09/paint-horse-running-in-field.jpg
# https://www.aspca.org/sites/default/files/blog_072117_house-senate-vote-horse-slaughter_main_1.jpg
# https://i.redd.it/a6me53rp6ha01.jpg
# https://i.ytimg.com/vi/y1U1Eqfdg7w/maxresdefault.jpg

# %%
folder = 'camels'
file = 'urls_camels.txt'
#file = 'horses.csv'

path = Path(my_path+'data/mammals')

dest = path/folder

download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#       <progress value='200' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:09<00:00]
#     </div>
# Error https://www.thenational.ae/image/policy:1.695004:1515936024/image/jpeg.jpg?f=16x9&w=1200&$p$f$w=dfa40e8 'content-length'
# Error 80/1920698/image.jpg Invalid URL '80/1920698/image.jpg': No schema supplied. Perhaps you meant http://80/1920698/image.jpg?
# Error https://www.nps.gov/whsa/learn/nature/images/Ancient_Camel.jpg?maxwidth=1200&maxheight=1200&autorotate=false 'content-length'
# Error https://www.giladorigami.com/P_Camel_Montroll.JPG 'content-length'
# Error f_auto Invalid URL 'f_auto': No schema supplied. Perhaps you meant http://f_auto?
# Error fl_progressive Invalid URL 'fl_progressive': No schema supplied. Perhaps you meant http://fl_progressive?
# Error q_80 Invalid URL 'q_80': No schema supplied. Perhaps you meant http://q_80?
# Error w_800/19cmjjuv9x7lajpg.jpg Invalid URL 'w_800/19cmjjuv9x7lajpg.jpg': No schema supplied. Perhaps you meant http://w_800/19cmjjuv9x7lajpg.jpg?
# Error http://www.zendmentravel.com/wp-content/uploads/2016/04/IMG_1016-1.jpg 'content-length'
# Error https://www.thenational.ae/image/policy:1.646140:1506086604/image/jpeg.jpg?f=16x9&w=1200&$p$f$w=dfa40e8 'content-length'
# Error h_1550 Invalid URL 'h_1550': No schema supplied. Perhaps you meant http://h_1550?
# Error c_limit/camels-plastic-surgery-disqualified-botox.jpg Invalid URL 'c_limit/camels-plastic-surgery-disqualified-botox.jpg': No schema supplied. Perhaps you meant http://c_limit/camels-plastic-surgery-disqualified-botox.jpg?
# Error http://i.bnet.com/blogs/camel.jpg 'content-length'
# Error http://www.oaklandzoo.org/WebApp-Images/Animals/Camel/Camel-2.jpg 'content-length'
# Error https://www.thenational.ae/image/policy:1.387269:1499549228/image/jpeg.jpg?f=16x9&w=1200&$p$f$w=dfa40e8 'content-length'
# Error width-400 Invalid URL 'width-400': No schema supplied. Perhaps you meant http://width-400?
# Error resizemode-4/62279997.jpg Invalid URL 'resizemode-4/62279997.jpg': No schema supplied. Perhaps you meant http://resizemode-4/62279997.jpg?
# Error imgsize-82012 Invalid URL 'imgsize-82012': No schema supplied. Perhaps you meant http://imgsize-82012?
# Error 0 Invalid URL '0': No schema supplied. Perhaps you meant http://0?
# Error 100 Invalid URL '100': No schema supplied. Perhaps you meant http://100?
# Error 430px Invalid URL '430px': No schema supplied. Perhaps you meant http://430px?
# Error https://spana.org/wp-content/uploads/2016/04/DSC_0492-rotate.jpg 'content-length'
# Error https://asknature.org/wp-content/uploads/strategy/c1eb0f25d3e091f568ce26c0c6f8646f/camel_feature.jpg 'content-length'

# %%
folder = 'horses'
file = 'urls_horses.txt'
#file = 'horses.csv'

path = Path(my_path+'data/mammals')

dest = path/folder

download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#       <progress value='200' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:07<00:00]
#     </div>
# Error http://www.horseradionetwork.com/wp-content/uploads/2018/01/hcr-54.jpg 'content-length'
# Error http://www.earthtimes.org/newsimage/wild-horses-america_1713.jpg 'content-length'
# Error https://manentailequine.com/files/2016/06/mobile-horse-2.jpg 'content-length'
# Error https://www.aljazeera.com/mritems/imagecache/mbdxxlarge/mritems/Images/2018/4/29/41b8692a81cc4f519bf8e0bf6113ea3d_18.jpg 'content-length'
# Error https://animalscience.unl.edu/Extension/Horse/Horsebanner2.jpg 'content-length'
# Error https://media.npr.org/assets/img/2018/07/10/dsc07545-1--3e78c902c20ebbf203b86800ebf0af3a442656dc-s800-c85.jpg 'content-length'
# Error 0.813 Invalid URL '0.813': No schema supplied. Perhaps you meant http://0.813?
# Error 0 Invalid URL '0': No schema supplied. Perhaps you meant http://0?
# Error 0.131 Invalid URL '0.131': No schema supplied. Perhaps you meant http://0.131?
# Error r4).jpg Invalid URL 'r4).jpg': No schema supplied. Perhaps you meant http://r4).jpg?
# Error https://cbsnews3.cbsistatic.com/hub/i/r/2018/09/11/a1d47f4a-5975-428d-88ed-356d74116c86/thumbnail/1200x630g8/0e2c9490d480d4706a96a33ea35b32bd/horses.jpg 'content-length'
# Error https://asset---north-carolina.bldg15.net/img/a/b/abdf2f11-79dd-4254-870c-6873afbeed03/Cape%20Lookout%20-%20Single%20Horse%20Close-Up-crop(1 'content-length'
# Error 50 Invalid URL '50': No schema supplied. Perhaps you meant http://50?
# Error https://quatr.us/wp-content/uploads/2017/06/horse-300x167.jpg 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=1988173908073179 'content-length'

# %%
#!ls /home/jupyter/tutorials/data/mammals/camels

# %%
# !ls /home/jupyter/tutorials/data/mammals/camels | wc -l
# Out:
# 177

# %%
#!ls /home/jupyter/tutorials/data/mammals/horses

# %%
# !ls /home/jupyter/tutorials/data/mammals/horses | wc -l
# Out:
# 185

# %% [markdown]
# ## Verify images

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
classes = ['camels','horses']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# camels
#     <div>
#       <progress value='177' max='177', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [177/177 00:04<00:00]
#     </div>
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000072.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000110.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000169.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000037.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000120.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000105.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000147.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000036.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000157.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000145.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000026.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000141.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/camels/00000095.jpg'
# horses
#     <div>
#       <progress value='185' max='185', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [185/185 00:04<00:00]
#     </div>
# cannot identify image file '/home/jupyter/tutorials/data/mammals/horses/00000035.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/horses/00000159.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/horses/00000110.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/horses/00000032.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/horses/00000167.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/horses/00000085.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/horses/00000158.jpg'
# /opt/anaconda3/lib/python3.6/site-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file '/home/jupyter/tutorials/data/mammals/horses/00000164.jpg'
# /opt/anaconda3/lib/python3.6/site-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file '/home/jupyter/tutorials/data/mammals/horses/00000150.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/mammals/horses/00000087.jpg'

# %%
# !ls /home/jupyter/tutorials/data/mammals/camels | wc -l
# Out:
# 164

# %%
# !ls /home/jupyter/tutorials/data/mammals/horses | wc -l
# Out:
# 175

# %% [markdown]
# ## View data

# %%
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2, ds_tfms=get_transforms(), size=224, num_workers=4)

# %%
(path).ls()
# Out:
# ['urls_camels.txt', 'camels', 'urls_horses.txt', 'models', 'horses']

# %%
#(path/'models').ls()

# %%
data.classes
# Out:
# ['camels', 'horses', 'models']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c
# Out:
# (['camels', 'horses', 'models'], 3)

# %% [markdown]
# ## Training: resnet34

# %% [markdown]
# Now we will start training our model. We will use a [convolutional neural network](http://cs231n.github.io/convolutional-networks/) backbone and a fully connected head with a single hidden layer as a classifier. Don't know what these things mean? Not to worry, we will dive deeper in the coming lessons. For the moment you need to know that we are building a model which will take images as input and will output the predicted probability for each of the categories (in this case, it will have 37 outputs).
#
# We will train for 4 epochs (4 cycles through all our data).

# %%
learn = ConvLearner(data, models.resnet34, metrics=error_rate)
#learn = Learner.create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:35
# epoch  train_loss  valid_loss  error_rate
# 1      1.220116    0.686683    0.285714    (00:09)
# 2      0.807073    0.375571    0.103896    (00:07)
# 3      0.640212    0.295698    0.051948    (00:09)
# 4      0.556612    0.225274    0.051948    (00:08)

# %%
learn.unfreeze()

# %%
learn.lr_find(stop_div=False)
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.save('stage-1')

# %%
#learn.fit_one_cycle(2, max_lr=slice(1e-5,1e-4))
learn.fit_one_cycle(2, max_lr=slice(1e-4,1e-3))
# Out:
# Total time: 00:17
# epoch  train_loss  valid_loss  error_rate
# 1      0.169633    0.141895    0.064935    (00:09)
# 2      0.138307    0.179179    0.038961    (00:08)

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %% [markdown]
# What the numbers represent:
# prediction | actual | loss | probability it was predicted

# %%
#interp.plot_top_losses(9)
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)

# %%
#interp.plot_confusion_matrix()
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('camels', 'horses', 3)]

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:08
# epoch  train_loss  valid_loss  error_rate
# 1      0.324069    2.842716    0.272727    (00:08)

# %%
learn.load('stage-1')

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 00:17
# epoch  train_loss  valid_loss  error_rate
# 1      0.350664    0.235548    0.051948    (00:08)
# 2      0.230442    0.193951    0.025974    (00:08)

# %% [markdown]
# That's a pretty accurate model!

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. Later in the course you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network might eat up our GPU memory.

# %%
path_img = "/home/jupyter/tutorials/data/mammals/"
fnames = ["camels", "horses"]

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=320, bs=bs//2)
data.normalize(imagenet_stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-7d2d2e53ec08> in <module>
# ----> 1 data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=320, bs=bs//2)
#       2 data.normalize(imagenet_stats)
#
# NameError: name 'pat' is not defined

# %%
learn = Learner.create_cnn(data, models.resnet50, metrics=error_rate)

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-3))

# %%
learn.save('stage-1-50')

# %% [markdown]
# >It's astonishing that it's possible to recognize pet breeds so accurately! Let's see if full fine-tuning helps:

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4))

# %% [markdown]
# In this case it doesn't, so let's go back to our previous model.

# %%
learn.load('stage-1-50')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused(min_val=2)
