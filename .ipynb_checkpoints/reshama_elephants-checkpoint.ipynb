# %% [markdown]
# ## Classifying:  African & Asian Elephants
# #### Reshama Shaikh
# #### 10/28/18

# %%
import fastai
fastai.show_install(0)
# Out:
# ```text
# === Software ===
# python version  : 3.6.5
# fastai version  : 1.0.14
# torch version   : 1.0.0.dev20181022
# nvidia driver   : 396.44
# torch cuda ver  : 9.2.148
# torch cuda is   : available
# torch cudnn ver : 7104
# torch cudnn is  : enabled
#
# === Hardware ===
# nvidia gpus     : 1
# torch available : 1
#   - gpu0        : 7611MB | Tesla P4
#
# === Environment ===
# platform        : Linux-4.9.0-8-amd64-x86_64-with-debian-9.5
# distro          : #1 SMP Debian 4.9.110-3+deb9u6 (2018-10-08)
# conda env       : Unknown
# python          : /opt/anaconda3/bin/python
# sys.path        :
# /opt/anaconda3/lib/python36.zip
# /opt/anaconda3/lib/python3.6
# /opt/anaconda3/lib/python3.6/lib-dynload
# /opt/anaconda3/lib/python3.6/site-packages
# /opt/anaconda3/lib/python3.6/site-packages/IPython/extensions
# /home/jupyter/.ipython
# ```
#
# Please make sure to include opening/closing ``` when you paste into forums/github to make the reports appear formatted as code sections.
#
# Optional package(s) to enhance the diagnostics can be installed with:
# pip install distro
# Once installed, re-run this utility to get the additional information

# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button. Then continue scrolling until you cannot scroll anymore. The maximum number of images Google Images shows is 700.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
my_path = "/home/jupyter/tutorials/"

# %%
folder = 'african'
file = 'urls_african.txt'

# %%
path = Path(my_path+'data/elephants')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %%
folder = 'asian'
file = 'urls_asian.txt'

# %%
path = Path(my_path+'data/elephants')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Finally, upload your urls file. You just need to press Upload in your working directory and select your file, then click 'upload' on the right.
#
# ![](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images than can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.

# %%
my_path = "/home/jupyter/tutorials/"

# %%
# !head {my_path}data/urls_african.txt
# Out:
# https://media.buzzle.com/media/images-en/gallery/mammals/elephants/1200-elephants-performing-tricks-before-trainer.jpg
# https://africageographic.com/wp-content/uploads/2017/03/Satao-II-a-6695-Dex-Kotze.jpg
# https://i.pinimg.com/736x/17/34/95/173495e502ec35d16b24070a6d0cbb14--happy-elephant-cute-baby-elephant.jpg
# https://i.pinimg.com/originals/57/39/13/573913e131f653e8b4600bba4a1e828b.jpg
# https://c402277.ssl.cf1.rackcdn.com/photos/885/images/carousel_small/African_Elephant_7.27.2012_whytheymatter_HI_58709.jpg?1345580947
# http://d2ouvy59p0dg6k.cloudfront.net/img/108954_374154.jpg
# https://news.nationalgeographic.com/content/dam/news/photos/000/306/30651.ngsversion.1421960098780.adapt.1900.1.jpg
# https://kids.sandiegozoo.org/sites/default/files/2017-07/elephant-tusks.jpg
# https://nails.newsela.com/s3/newsela-media/article_media/2018/01/elem-es-african-elephant-dfbc68c5.jpg?crop=0%2C93%2C1366%2C860&height=496&width=885
# https://elephantconservation.org/iefImages/2009/12/afele1.jpg

# %% [markdown]
# #### move url files to folder
# ```bash
# mv urls_african.txt elephants/
# mv urls_asian.txt elephants/
# ```
# ```bash
# jupyter@my-fastai-instance:~/tutorials/data$ mv urls_african.txt elephants/
# jupyter@my-fastai-instance:~/tutorials/data$ mv urls_asian.txt elephants/
# ```

# %%
folder = 'african'
file = 'urls_african.txt'

path = Path(my_path+'data/elephants')

dest = path/folder

download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#       <progress value='200' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:13<00:00]
#     </div>
# Error f_auto Invalid URL 'f_auto': No schema supplied. Perhaps you meant http://f_auto?
# Error q_80 Invalid URL 'q_80': No schema supplied. Perhaps you meant http://q_80?
# Error w_800/xnvmlsgtghn9ezsf85iv.jpg Invalid URL 'w_800/xnvmlsgtghn9ezsf85iv.jpg': No schema supplied. Perhaps you meant http://w_800/xnvmlsgtghn9ezsf85iv.jpg?
# Error fl_progressive Invalid URL 'fl_progressive': No schema supplied. Perhaps you meant http://fl_progressive?
# Error http://www.krugerpark.co.za/images/1-kruger-park-elephant-calf-duplessis-590.jpg 'content-length'
# Error http://www.elephantsforafrica.org/wp-content/uploads/2012/11/baby-african-elephant-facts.jpg 'content-length'
# Error https://1d59b73swr1f1swu2v451xcx-wpengine.netdna-ssl.com/wp-content/uploads/strategy/6b642c93e7426b6d86fe5b1ad6c5c7ae/afrikanischer_elefant_miami.jpg 'content-length'
# Error 0 Invalid URL '0': No schema supplied. Perhaps you meant http://0?
# Error 3520 Invalid URL '3520': No schema supplied. Perhaps you meant http://3520?
# Error 2200&wid=1640&hei=1025&scl=2.1463414634146343 Invalid URL '2200&wid=1640&hei=1025&scl=2.1463414634146343': No schema supplied. Perhaps you meant http://2200&wid=1640&hei=1025&scl=2.1463414634146343?
# Error http://31dxg91v5jkg1h3wy326n6eeq1c.wpengine.netdna-cdn.com/files/2016/08/HI_112369.jpg 'content-length'
# Error http://31dxg91v5jkg1h3wy326n6eeq1c.wpengine.netdna-cdn.com/files/2016/08/SCR_113023-1024x683.jpg 'content-length'
# Error 284 Invalid URL '284': No schema supplied. Perhaps you meant http://284?
# Error 4928 Invalid URL '4928': No schema supplied. Perhaps you meant http://4928?
# Error 2710&wid=4000&hei=2200&scl=1.232 Invalid URL '2710&wid=4000&hei=2200&scl=1.232': No schema supplied. Perhaps you meant http://2710&wid=4000&hei=2200&scl=1.232?
# Error 574 Invalid URL '574': No schema supplied. Perhaps you meant http://574?
# Error https://www.traffic.org/site/assets/files/1786/species-elephants.-1800w.1530280317.jpg 'content-length'

# %%
folder = 'asian'
file = 'urls_asian.txt'

path = Path(my_path+'data/elephants')

dest = path/folder

download_images(path/file, dest, max_pics=200)
# Out:
#     <div>
#       <progress value='200' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 02:22<00:00]
#     </div>
# Error http://itsnature.org/wp-content/uploads/2010/02/asianelephant11.jpg 'content-length'
# Error https://o.aolcdn.com/images/dims3/GLOB/crop/944x473+0+30/resize/630x315!/format/jpg/quality/85/http%3A%2F%2Fo.aolcdn.com%2Fhss%2Fstorage%2Fmidas%2Fa4a0db46de604059622e539e3fc58448%2F205481113%2FGenieHerd.png 'content-length'
# Error https://journals.plos.org/plosone/article/figure/image?size=inline&id=10.1371/journal.pone.0082788.g002 'content-length'
# Error https://images.theconversation.com/files/9800/original/n6wp9t3z-1334884998.jpg?ixlib=rb-1.1.0&q=45&auto=format&w=1012&h=668&fit=crop 'content-length'
# Error http://i1-news.softpedia-static.com/images/news2/Climate-Change-Argued-to-Kill-Numerous-Baby-Elephants-2.jpg HTTPConnectionPool(host='i1-news.softpedia-static.com', port=80): Max retries exceeded with url: /images/news2/Climate-Change-Argued-to-Kill-Numerous-Baby-Elephants-2.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7f2dd01417f0>: Failed to establish a new connection: [Errno 110] Connection timed out',))

# %%
#!ls /home/jupyter/tutorials/data/elephants/african

# %%
# !ls /home/jupyter/tutorials/data/elephants/african | wc -l
# Out:
# 183

# %%
# !ls /home/jupyter/tutorials/data/elephants/asian | wc -l
# Out:
# 195

# %% [markdown]
# ## Verify images

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
classes = ['african','asian']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# african
#     <div>
#       <progress value='183' max='183', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [183/183 00:04<00:00]
#     </div>
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000172.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000035.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000118.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000110.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000124.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000012.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000176.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000098.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000057.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000164.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000136.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000100.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000078.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000151.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000107.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000194.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000138.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/african/00000170.jpg'
# asian
#     <div>
#       <progress value='195' max='195', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [195/195 00:04<00:00]
#     </div>
# cannot identify image file '/home/jupyter/tutorials/data/elephants/asian/00000010.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/asian/00000051.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/asian/00000133.jpg'
# /opt/anaconda3/lib/python3.6/site-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file '/home/jupyter/tutorials/data/elephants/asian/00000185.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/asian/00000144.jpg'
# cannot identify image file '/home/jupyter/tutorials/data/elephants/asian/00000090.jpg'

# %%
# !ls /home/jupyter/tutorials/data/mammals/camels | wc -l
# Out:
# 164

# %%
# !ls /home/jupyter/tutorials/data/mammals/horses | wc -l
# Out:
# 175

# %% [markdown]
# ## View data

# %%
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2, ds_tfms=get_transforms(), size=224, num_workers=4)

# %%
(path).ls()
# Out:
# ['asian', 'african', 'urls_african.txt', 'urls_asian.txt']

# %%
data.classes
# Out:
# ['african', 'asian']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c
# Out:
# (['african', 'asian'], 2)

# %% [markdown]
# ## Training: resnet34

# %% [markdown]
# Now we will start training our model. We will use a [convolutional neural network](http://cs231n.github.io/convolutional-networks/) backbone and a fully connected head with a single hidden layer as a classifier. Don't know what these things mean? Not to worry, we will dive deeper in the coming lessons. For the moment you need to know that we are building a model which will take images as input and will output the predicted probability for each of the categories (in this case, it will have 37 outputs).
#
# We will train for 4 epochs (4 cycles through all our data).

# %% [markdown]
# ## Training: resnet34 (CNN) ---> classify elephants

# %%
learn = ConvLearner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# Total time: 00:36
# epoch  train_loss  valid_loss  error_rate
# 1      0.730337    0.809354    0.432836    (00:11)
# 2      0.549506    0.993004    0.402985    (00:08)
# 3      0.480510    1.044122    0.388060    (00:08)
# 4      0.419604    0.854204    0.298507    (00:08)

# %%
learn.unfreeze()

# %%
learn.lr_find(stop_div=False)
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.save('stage-1')

# %%
#learn.fit_one_cycle(2, max_lr=slice(1e-5,1e-4))
learn.fit_one_cycle(2, max_lr=slice(1e-4,1e-3))
# Out:
# Total time: 00:18
# epoch  train_loss  valid_loss  error_rate
# 1      0.343066    0.696139    0.164179    (00:08)
# 2      0.334749    1.065531    0.253731    (00:10)

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %% [markdown]
# What the numbers represent:
# prediction | actual | loss | probability it was predicted

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
doc(interp.plot_top_losses)

# %%
#interp.plot_confusion_matrix()
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)

# %%
interp.most_confused(min_val=2)
# Out:
# [('asian', 'african', 9), ('african', 'asian', 8)]

# %% [markdown]
# ## Unfreezing, fine-tuning, and learning rates

# %% [markdown]
# Since our model is working as we expect it to, we will *unfreeze* our model and train some more.

# %%
learn.unfreeze()

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:08
# epoch  train_loss  valid_loss  error_rate
# 1      0.661055    10.593487   0.641791    (00:08)

# %%
learn.load('stage-1')

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.unfreeze()
learn.fit_one_cycle(2, max_lr=slice(1e-6,1e-4))
# Out:
# Total time: 00:16
# epoch  train_loss  valid_loss  error_rate
# 1      0.239210    0.705375    0.223881    (00:07)
# 2      0.255059    0.636563    0.194030    (00:08)

# %% [markdown]
# >That's a pretty accurate model

# %% [markdown]
# ## Training: resnet50

# %% [markdown]
# Now we will train in the same way as before but with one caveat: instead of using resnet34 as our backbone we will use resnet50 (resnet34 is a 34 layer residual network while resnet50 has 50 layers. Later in the course you can learn the details in the [resnet paper](https://arxiv.org/pdf/1512.03385.pdf)).
#
# Basically, resnet50 usually performs better because it is a deeper network with more parameters. Let's see if we can achieve a higher performance here. To help it along, let's us larger images too, since that way the network can see more detail. We reduce the batch size a bit since otherwise this larger network might eat up our GPU memory.

# %%
path_img = "/home/jupyter/tutorials/data/elephants/"
fnames = ["african", "asian"]

# %%
# ?ImageDataBunch

# %%
data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=320, bs=bs//2)
data.normalize(imagenet_stats)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-7d2d2e53ec08> in <module>
# ----> 1 data = ImageDataBunch.from_name_re(path_img, fnames, pat, ds_tfms=get_transforms(), size=320, bs=bs//2)
#       2 data.normalize(imagenet_stats)
#
# NameError: name 'pat' is not defined

# %%
learn = Learner.create_cnn(data, models.resnet50, metrics=error_rate)

# %%
learn.fit_one_cycle(8, max_lr=slice(1e-3))

# %%
learn.save('stage-1-50')

# %% [markdown]
# >It's astonishing that it's possible to recognize pet breeds so accurately! Let's see if full fine-tuning helps:

# %%
learn.unfreeze()
learn.fit_one_cycle(3, max_lr=slice(1e-6,1e-4))

# %% [markdown]
# In this case it doesn't, so let's go back to our previous model.

# %%
learn.load('stage-1-50')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.most_confused(min_val=2)
